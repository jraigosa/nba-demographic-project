# %%
#Dependencies
import pandas as pd
import numpy as np

# %%
#Import data, ignore first column in Players.csv

cols = range(1,8)
players = pd.read_csv("../Resources/original_data/Players.csv", usecols=cols)
player_data = pd.read_csv("../Resources/original_data/player_data.csv")

# %%
#Drop unwanted column and rename player column

players.drop(columns=['born', 'weight'], inplace=True)
players.rename(columns={"Player": "name", "collage": "college"}, inplace=True)

# %%
#Create seasons_played column using year_start and year_end

player_data['seasons_played'] = player_data['year_end'] - player_data['year_start']

# %%
#Drop unwanted columns

player_data.drop(columns=['year_start', 'year_end', 'height', 'weight'], inplace=True)

# %%
#Drop rows with no data for birth location

players.dropna(subset=['birth_city', 'birth_state'], inplace=True)

# %%
#Merge the two dataframes on player name and college attended

players_merged = pd.merge(players, player_data, on=["name", "college"], how="outer")

# %%
#Drop rows with no data for birth location

players_merged.dropna(subset=['birth_city', 'birth_state'], inplace=True)

# %%
players_merged
# Out:
#                    name  height                          college  \
# 0          Cliff Barker   188.0           University of Kentucky
# 1           Ralph Beard   178.0           University of Kentucky
# 2         Charlie Black   196.0             University of Kansas
# 3           Nelson Bobb   183.0                Temple University
# 4       Jake Bornheimer   196.0               Muhlenberg College
# ...                 ...     ...                              ...
# 3437      Troy Williams   198.0  South Carolina State University
# 3438       Kyle Wiltjer   208.0               Gonzaga University
# 3439  Stephen Zimmerman   213.0  University of Nevada, Las Vegas
# 3440        Paul Zipser   203.0                              NaN
# 3441        Ivica Zubac   216.0                              NaN
#
#           birth_city             birth_state position         birth_date  \
# 0           Yorktown                 Indiana        G   January 15, 1921
# 1        Hardinsburg                Kentucky        G   December 2, 1927
# 2               Arco                   Idaho      F-C      June 15, 1921
# 3       Philadelphia            Pennsylvania        G  February 25, 1924
# 4      New Brunswick              New Jersey      F-C      June 29, 1927
# ...              ...                     ...      ...                ...
# 3437        Columbia          South Carolina      NaN                NaN
# 3438        Portland                  Oregon        F   October 20, 1992
# 3439  Hendersonville               Tennessee        C  September 9, 1996
# 3440      Heidelberg                 Germany      G-F  February 18, 1994
# 3441          Mostar  Bosnia and Herzegovina        C     March 18, 1997
#
#       seasons_played
# 0                2.0
# 1                1.0
# 2                3.0
# 3                3.0
# 4                1.0
# ...              ...
# 3437             NaN
# 3438             0.0
# 3439             0.0
# 3440             1.0
# 3441             1.0
#
# [3442 rows x 8 columns]

# %%
US_states = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","District of Columbia","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# %%
us_df = players_merged[players_merged['birth_state'].isin(US_states)]
us_df
# Out:
#                    name  height                          college  \
# 0          Cliff Barker   188.0           University of Kentucky
# 1           Ralph Beard   178.0           University of Kentucky
# 2         Charlie Black   196.0             University of Kansas
# 3           Nelson Bobb   183.0                Temple University
# 4       Jake Bornheimer   196.0               Muhlenberg College
# ...                 ...     ...                              ...
# 3435        Okaro White   203.0         Florida State University
# 3436   Isaiah Whitehead   193.0            Seton Hall University
# 3437      Troy Williams   198.0  South Carolina State University
# 3438       Kyle Wiltjer   208.0               Gonzaga University
# 3439  Stephen Zimmerman   213.0  University of Nevada, Las Vegas
#
#           birth_city     birth_state position         birth_date  \
# 0           Yorktown         Indiana        G   January 15, 1921
# 1        Hardinsburg        Kentucky        G   December 2, 1927
# 2               Arco           Idaho      F-C      June 15, 1921
# 3       Philadelphia    Pennsylvania        G  February 25, 1924
# 4      New Brunswick      New Jersey      F-C      June 29, 1927
# ...              ...             ...      ...                ...
# 3435      Clearwater         Florida        F    August 13, 1992
# 3436        Brooklyn        New York        G      March 8, 1995
# 3437        Columbia  South Carolina      NaN                NaN
# 3438        Portland          Oregon        F   October 20, 1992
# 3439  Hendersonville       Tennessee        C  September 9, 1996
#
#       seasons_played
# 0                2.0
# 1                1.0
# 2                3.0
# 3                3.0
# 4                1.0
# ...              ...
# 3435             1.0
# 3436             1.0
# 3437             NaN
# 3438             0.0
# 3439             0.0
#
# [3059 rows x 8 columns]

# %%
us_df['birth_city'].value_counts().head(10)
# Out:
# Chicago         114
# Los Angeles      88
# Philadelphia     83
# Brooklyn         76
# New York         71
# Washington       62
# Detroit          58
# Baltimore        37
# Atlanta          37
# Dallas           33
# Name: birth_city, dtype: int64

# %%
us_df['birth_state'].value_counts().head(10)
# Out:
# California        345
# New York          290
# Illinois          209
# Pennsylvania      163
# Ohio              137
# Michigan          131
# Texas             129
# Georgia           118
# Louisiana         101
# North Carolina     96
# Name: birth_state, dtype: int64

# %%
international = players_merged[~players_merged['birth_state'].isin(US_states)]
international
# Out:
#                   name  height                             college  \
# 64          Lee Knorek   201.0         University of Detroit Mercy
# 131   Ernie Vandeweghe   190.0                  Colgate University
# 184      Bob Houbregs*   201.0            University of Washington
# 217       Chris Harris   190.0                University of Dayton
# 314       Tom Meschery   198.0  Saint Mary's College of California
# ...                ...     ...                                 ...
# 3424       Dario Saric   208.0                                 NaN
# 3425  Tomas Satoransky   201.0                                 NaN
# 3427     Pascal Siakam   206.0         New Mexico State University
# 3440       Paul Zipser   203.0                                 NaN
# 3441       Ivica Zubac   216.0                                 NaN
#
#             birth_city             birth_state position          birth_date  \
# 64              Warsaw                  Poland        C       July 15, 1921
# 131           Montreal                  Canada      F-G  September 12, 1928
# 184          Vancouver                  Canada      NaN                 NaN
# 217        Southampton          United Kingdom        G     August 11, 1933
# 314   Harbin Manchuria                   China        F    October 26, 1938
# ...                ...                     ...      ...                 ...
# 3424           Sibenik                 Croatia        F       April 8, 1994
# 3425            Prague          Czech Republic        G    October 30, 1991
# 3427            Douala                Cameroon        F    February 4, 1994
# 3440        Heidelberg                 Germany      G-F   February 18, 1994
# 3441            Mostar  Bosnia and Herzegovina        C      March 18, 1997
#
#       seasons_played
# 64               3.0
# 131              6.0
# 184              NaN
# 217              0.0
# 314              9.0
# ...              ...
# 3424             1.0
# 3425             1.0
# 3427             1.0
# 3440             1.0
# 3441             1.0
#
# [383 rows x 8 columns]

# %%
international['birth_state'].value_counts().head(20)
# Out:
# Canada                    26
# Serbia                    20
# France                    19
# Germany                   17
# Croatia                   16
# Brazil                    15
# Spain                     14
# Australia                 13
# Argentina                 12
# Bosnia and Herzegovina    11
# Lithuania                 11
# Russia                    10
# Slovenia                   9
# Nigeria                    9
# United Kingdom             9
# Senegal                    8
# Greece                     8
# Ukraine                    8
# Italy                      7
# Jamaica                    7
# Name: birth_state, dtype: int64

# %%
us_df.to_csv('US_players.csv')
